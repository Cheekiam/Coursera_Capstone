# %% [markdown]
# ### Description of the data used
#
# Below is just a sample of the data. Each grouping contain the Neighbourhood names with common postcodes, and each group have 10 most venues frequencies recorded.
# The full data set is also used to produce other tables which I will not be showing until week 5 of the assignment due date.
#
# As can be seen from the sample data, the frequency score will able to tell what kind of venues occupy those district at the time the data was obtained. From here a simple conclusion can be about the suitability of the restaurant to be situated from the combination of other information.

# %% [markdown]
# ----Adelaide, King, Richmond----
#
#                   venue  freq
#
#     0       Coffee Shop  0.07
#
#     1              Café  0.05
#
#     2   Thai Restaurant  0.04
#
#     3        Steakhouse  0.04
#
#     4               Bar  0.04
#
#     5    Cosmetics Shop  0.03
#
#     6  Asian Restaurant  0.03
#
#     7        Restaurant  0.03
#
#     8             Hotel  0.03
#
#     9               Gym  0.03
#
#
# ----Berczy Park----
#
#                     venue  freq
#
#     0         Coffee Shop  0.09
#
#     1        Cocktail Bar  0.05
#
#     2              Bakery  0.05
#
#     3                Café  0.04
#
#     4         Cheese Shop  0.04
#
#     5  Seafood Restaurant  0.04
#
#     6            Beer Bar  0.04
#
#     7      Farmers Market  0.04
#
#     8          Steakhouse  0.04
#
#     9            Creperie  0.02
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#
#                         venue  freq
#
#     0          Breakfast Spot  0.09
#
#     1                    Café  0.09
#
#     2             Coffee Shop  0.09
#
#     3               Pet Store  0.04
#
#     4           Grocery Store  0.04
#
#     5    Caribbean Restaurant  0.04
#
#     6                 Stadium  0.04
#
#     7  Furniture / Home Store  0.04
#
#     8      Falafel Restaurant  0.04
#
#     9               Nightclub  0.04
#
#
#
# ........more to follow......
